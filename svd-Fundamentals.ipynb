# %% [markdown]
# ### Import Libraries:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer

# %% [markdown]
# ### Load the dataset:

# %%
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ### Checking Columns:

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %% [markdown]
# >Process the data:

# %% [markdown]
# >Selecting Features for SVD:

# %%
features = ['pclass','sex','age','fare','embarked']
x=df[features]

# %%
x
# Out:
#      pclass     sex   age     fare embarked
# 0         3    male  22.0   7.2500        S
# 1         1  female  38.0  71.2833        C
# 2         3  female  26.0   7.9250        S
# 3         1  female  35.0  53.1000        S
# 4         3    male  35.0   8.0500        S
# ..      ...     ...   ...      ...      ...
# 886       2    male  27.0  13.0000        S
# 887       1  female  19.0  30.0000        S
# 888       3  female   NaN  23.4500        S
# 889       1    male  26.0  30.0000        C
# 890       3    male  32.0   7.7500        Q
#
# [891 rows x 5 columns]

# %% [markdown]
# ### Pipeline for numerical features:

# %%
numeric_features = ['age','fare']
numeric_transformer = Pipeline(steps=[('imputer',SimpleImputer(strategy='median')),('scaler',StandardScaler())])

# %%
numeric_transformer
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                 ('scaler', StandardScaler())])

# %% [markdown]
# ### Pipeline for Categorical Features:

# %%
categorical_features = ['pclass', 'sex']
categorical_transformer = Pipeline(steps=[('imputer', SimpleImputer(strategy='constant', fill_value='missing')), ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# %%
categorical_transformer
# Out:
# Pipeline(steps=[('imputer',
#                  SimpleImputer(fill_value='missing', strategy='constant')),
#                 ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# %% [markdown]
# ### Preprocessor:

# %%
preprocessor = ColumnTransformer(transformers=[('num',numeric_transformer,numeric_features),('cat',categorical_transformer,categorical_features)])

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  ['age', 'fare']),
#                                 ('cat',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(fill_value='missing',
#                                                                 strategy='constant')),
#                                                  ('onehot',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  ['pclass', 'sex'])])

# %% [markdown]
# ### Applying Preprocessing to the dataset:

# %%
x = preprocessor.fit_transform(df)

# %%
x
# Out:
# array([[-0.56573646, -0.50244517,  0.        , ...,  1.        ,
#          0.        ,  1.        ],
#        [ 0.66386103,  0.78684529,  1.        , ...,  0.        ,
#          1.        ,  0.        ],
#        [-0.25833709, -0.48885426,  0.        , ...,  1.        ,
#          1.        ,  0.        ],
#        ...,
#        [-0.1046374 , -0.17626324,  0.        , ...,  1.        ,
#          1.        ,  0.        ],
#        [-0.25833709, -0.04438104,  1.        , ...,  0.        ,
#          0.        ,  1.        ],
#        [ 0.20276197, -0.49237783,  0.        , ...,  1.        ,
#          0.        ,  1.        ]], shape=(891, 7))

# %% [markdown]
# ### Finding shape of the array:

# %%
x.shape
# Out:
# (891, 7)

# %% [markdown]
# #### Perform Singular Value Decomposition SVD:

# %%
svd = TruncatedSVD(n_components=2)

# %%
Y = svd.fit_transform(x)
print("Singular Values:",svd.singular_values_)
print("Explained Variance Ratio:",svd.explained_variance_ratio_)
# Out:
# Singular Values: [34.0919237  29.83381513]
# Explained Variance Ratio: [0.37544109 0.16349524]

# %% [markdown]
# ##### Assuming Y is the result from SVD with components:

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
plt.scatter(Y[:,0],Y[:,1],c=df['survived'],alpha=0.5)
plt.xlabel('SVD Component 1')
plt.ylabel('SVD Component 2')
plt.title('Truncated SVD of Titanic Dataset')
plt.grid(True)
plt.show()

# %% [markdown]
# *** ***

# %% [markdown]
# >Assuming 'Survived' is the last column in the features u selected

# %%
categories = df['survived'].values  # Extract the survival status as categories
plt.figure(figsize=(10,6))
scatter = plt.scatter(Y[:,0],Y[:,1],c=categories,cmap='viridis',alpha=0.5)
plt.xlabel('SVD Component 1')
plt.ylabel('SVD Component 2')
plt.title('SVD of Titanic Dataset')
plt.legend(*scatter.legend_elements(),title='Survived')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 3
#       1 Categories = df['survived'].values #Extract the survival status as categories
#       2 plt.figure(figsize=(10,6))
# ----> 3 scatter = plt.scatter(Y[:,0],Y[:,1],c=Categories,cmap='virdis',alpha=0.5)
#       4 plt.xlabel('SVD Component 1')
#       5 plt.ylabel('SVD Component 2')
#
# File c:\Users\RGB LAPTOPS\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
# ...
